# %%
cd("/u/home/t/ttthach/187/DrugResponseModel.jl/")

import Pkg; Pkg.instantiate()
Pkg.activate(".")
using DelimitedFiles
using Plots
using Measures
using LinearAlgebra
using Statistics
using DSP: conv
using BlackBoxOptim
using JLD
using Distributions
using DataFrames
using XLSX
using StatsPlots
using NumericalIntegration
using CSV
using MultivariateStats
using Impute
using DrugResponseModel


concs, popul1, g1s1, g2s1 = DrugResponseModel.load(189, 1)
_, popul2, g1s2, g2s2 = DrugResponseModel.load(189, 2)
_, popul3, g1s3, g2s3 = DrugResponseModel.load(189, 3)

# find the average of the three replicates
g1S = cat(g1s1, g1s2, g1s3, dims = 4)
g2S = cat(g2s1, g2s2, g2s3, dims = 4)
g1m = mean(g1S, dims = 4) # mean G1
g2m = mean(g2S, dims = 4) # mean G2

time = LinRange(0.0, 94.5, 189)
# Out:
#   Activating project at `~/187/DrugResponseModel.jl`
# 189-element LinRange{Float64, Int64}:
#  0.0,0.50266,1.00532,1.50798,2.01064,…,92.4894,92.992,93.4947,93.9973,94.5

# %%
g_costs = []
g_hills = []
for i in 1:10
    g_cost, g_hill = optimize_hill(concs[:, 3], g1m[:, :, 3], g2m[:, :, 3], 
                                    maxstep = 200000, num_parts = 4, 
                                    g1_lower = 1, g1_upper = 4, g2_lower = 4, g2_upper = 10)
    
    println("Iteration $i")
    println(g_cost)
    println(g_hill)
    println()
    
    push!(g_costs, g_cost)
    push!(g_hills, g_hill)

    
end
# Out:
# Starting optimization with optimizer DiffEvoOpt{FitPopulation{Float64}, RadiusLimitedSelector, BlackBoxOptim.AdaptiveDiffEvoRandBin{3}, RandomBound{ContinuousRectSearchSpace}}
# 0.00 secs, 0 evals, 0 steps
# DE modify state:
# 100.00 secs, 18164 evals, 18040 steps, improv/step: 0.143 (last = 0.1426), fitness=349.610234298
# DE modify state:
# 200.01 secs, 32699 evals, 32576 steps, improv/step: 0.151 (last = 0.1616), fitness=288.493180369
# DE modify state:
# 300.01 secs, 47246 evals, 47123 steps, improv/step: 0.150 (last = 0.1479), fitness=271.802492328
# DE modify state:
# 400.01 secs, 62027 evals, 61904 steps, improv/step: 0.154 (last = 0.1643), fitness=228.974736616
# DE modify state:
# 500.02 secs, 76853 evals, 76731 steps, improv/step: 0.151 (last = 0.1420), fitness=223.859337314
# DE modify state:
# 600.02 secs, 91927 evals, 91806 steps, improv/step: 0.151 (last = 0.1473), fitness=222.554626419
# DE modify state:
# 700.02 secs, 107415 evals, 107296 steps, improv/step: 0.151 (last = 0.1556), fitness=220.378439668
# DE modify state:
# 800.03 secs, 123011 evals, 122893 steps, improv/step: 0.152 (last = 0.1539), fitness=219.863552708
# DE modify state:
# 900.03 secs, 138520 evals, 138402 steps, improv/step: 0.152 (last = 0.1515), fitness=219.808128745
# DE modify state:
# 1000.03 secs, 154192 evals, 154075 steps, improv/step: 0.150 (last = 0.1317), fitness=219.804572813
# DE modify state:
# 1100.04 secs, 169935 evals, 169820 steps, improv/step: 0.149 (last = 0.1430), fitness=219.803446726
# DE modify state:
# 1200.04 secs, 185672 evals, 185558 steps, improv/step: 0.147 (last = 0.1281), fitness=219.803172641
# DE modify state:
#
# Optimization stopped after 200001 steps and 1292.68 seconds
# Termination reason: Max number of steps (200000) reached
# Steps per second = 154.72
# Function evals per second = 154.80
# Improvements/step = 0.14571
# Total function evaluations = 200113
#
#
# Best candidate found: [5.59073, 1.88417, 4.0, 4.0, 0.363932, 0.315138, 0.760701, 2.66112, 0.4789, 0.448994, 1.07697e-8, 2.73429e-9, 1.27227e-9, 1.1405e-9, 2.72926e-9, 2.27923e-9, 0.0906707, 2.94423e-9, 4.0, 3.99999, 0.168586, 1.69478, 2.08581, 4.0, 4.0, 0.38569, 3.52167, 9.48327]
#
# Fitness: 219.803094189
#
# Iteration 1
# 219.80309418869325
# [5.590732839421281, 1.8841702141398549, 3.9999999629431606, 3.9999990122614713, 0.3639321838842687, 0.31513831816076665, 0.7607012717125647, 2.6611158896898033, 0.47890037821302506, 0.44899447956678773, 1.0769660590285188e-8, 2.7342865809550765e-9, 1.2722747234432964e-9, 1.1405042798000597e-9, 2.729260747935698e-9, 2.2792327340757573e-9, 0.09067073947211271, 2.9442306290228044e-9, 3.9999997476053872, 3.9999930824682863, 0.16858625399917956, 1.6947789702094869, 2.085809420700082, 3.999995991246871, 3.9999999259045906, 0.38569006833756464, 3.521669715337219, 9.483273667451845]
#
# Starting optimization with optimizer DiffEvoOpt{FitPopulation{Float64}, RadiusLimitedSelector, BlackBoxOptim.AdaptiveDiffEvoRandBin{3}, RandomBound{ContinuousRectSearchSpace}}
# 0.00 secs, 0 evals, 0 steps
# DE modify state:
# 100.01 secs, 21094 evals, 20986 steps, improv/step: 0.094 (last = 0.0944), fitness=430.748337924
# DE modify state:
# 200.01 secs, 38898 evals, 38790 steps, improv/step: 0.107 (last = 0.1228), fitness=279.855373320
# DE modify state:
# 300.01 secs, 56448 evals, 56340 steps, improv/step: 0.116 (last = 0.1337), fitness=228.584030458
# DE modify state:
# 400.02 secs, 74592 evals, 74484 steps, improv/step: 0.121 (last = 0.1393), fitness=215.819516992
# DE modify state:
# 500.02 secs, 92985 evals, 92879 steps, improv/step: 0.126 (last = 0.1456), fitness=215.251800323
# DE modify state:
# 600.02 secs, 110636 evals, 110533 steps, improv/step: 0.128 (last = 0.1396), fitness=215.129505172
# DE modify state:
# 700.03 secs, 128239 evals, 128137 steps, improv/step: 0.130 (last = 0.1431), fitness=215.118701251
# DE modify state:
# 800.03 secs, 145367 evals, 145267 steps, improv/step: 0.129 (last = 0.1219), fitness=215.116982556
# DE modify state:
# 900.03 secs, 162545 evals, 162447 steps, improv/step: 0.131 (last = 0.1445), fitness=215.116832724
# DE modify state:
# 1000.04 secs, 179868 evals, 179772 steps, improv/step: 0.130 (last = 0.1255), fitness=215.116794416
# DE modify state:
# 1100.04 secs, 196787 evals, 196697 steps, improv/step: 0.129 (last = 0.1179), fitness=215.116791361
# DE modify state:
#
# Optimization stopped after 200001 steps and 1119.17 seconds
# Termination reason: Max number of steps (200000) reached
# Steps per second = 178.70
# Function evals per second = 178.79
# Improvements/step = 0.12888
# Total function evaluations = 200091
#
#
# Best candidate found: [5.58644, 1.90971, 0.345032, 1.05264, 0.909911, 0.793468, 0.54418, 0.459689, 4.0, 0.394469, 1.00876e-9, 1.08035e-9, 1.02873e-9, 1.31616e-9, 1.07383e-9, 0.0993994, 1.25531e-9, 1.05902e-9, 0.157912, 4.0, 4.0, 4.0, 1.42516, 4.0, 4.0, 0.354488, 3.19367, 8.13147]
#
# Fitness: 215.116791296
#
# Iteration 2
# 215.11679129567622
# [5.586439557402862, 1.9097084902023727, 0.3450316404265068, 1.0526404848200692, 0.9099114608808101, 0.793467984664723, 0.544180406148688, 0.4596892362907639, 3.9999999153864145, 0.3944690717076684, 1.0087572631819311e-9, 1.0803526301141115e-9, 1.0287251070515337e-9, 1.3161583534668335e-9, 1.0738286275955157e-9, 0.09939937770241795, 1.2553129974314092e-9, 1.0590153768694126e-9, 0.15791204224924468, 3.9999998739048657, 3.999999879289571, 3.99999990263533, 1.4251584938730053, 3.9999999971522877, 3.9999999700385644, 0.3544878329594083, 3.193667735582123, 8.131471872873178]
#
# Starting optimization with optimizer DiffEvoOpt{FitPopulation{Float64}, RadiusLimitedSelector, BlackBoxOptim.AdaptiveDiffEvoRandBin{3}, RandomBound{ContinuousRectSearchSpace}}
# 0.00 secs, 0 evals, 0 steps
# DE modify state:
# 100.01 secs, 20111 evals, 20004 steps, improv/step: 0.090 (last = 0.0899), fitness=456.483253326
# DE modify state:
# 200.01 secs, 37820 evals, 37714 steps, improv/step: 0.120 (last = 0.1551), fitness=316.134237660
# DE modify state:
# 300.01 secs, 64657 evals, 64553 steps, improv/step: 0.125 (last = 0.1309), fitness=290.740405143
# DE modify state:
# 400.01 secs, 91957 evals, 91855 steps, improv/step: 0.131 (last = 0.1441), fitness=245.446648308
# DE modify state:
# 500.01 secs, 117138 evals, 117037 steps, improv/step: 0.134 (last = 0.1478), fitness=235.075914114
# DE modify state:
# 600.02 secs, 142224 evals, 142125 steps, improv/step: 0.138 (last = 0.1557), fitness=231.697999780
# DE modify state:
# 700.02 secs, 167561 evals, 167463 steps, improv/step: 0.142 (last = 0.1640), fitness=231.629835049
# DE modify state:
# 800.02 secs, 192535 evals, 192439 steps, improv/step: 0.142 (last = 0.1417), fitness=231.629580503
# DE modify state:
#
# Optimization stopped after 200001 steps and 830.12 seconds
# Termination reason: Max number of steps (200000) reached
# Steps per second = 240.93
# Function evals per second = 241.05
# Improvements/step = 0.14130
# Total function evaluations = 200097
#
#
# Best candidate found: [4.6199, 2.38302, 4.0, 4.0, 0.240707, 0.14224, 1.13779, 0.10383, 0.781883, 4.0, 1.19639e-9, 5.19949e-9, 1.04298e-9, 0.069356, 1.22299e-9, 1.04241e-9, 1.3132e-9, 3.90643e-9, 3.99968, 3.99983, 0.161134, 4.0, 4.0, 0.307146, 0.621736, 3.99192, 3.10037, 6.21317]
#
# Fitness: 231.629575992
#
# Iteration 3
# 231.6295759923968
# [4.619898089907969, 2.3830192114869146, 3.9999987351961526, 3.999999708606659, 0.24070708978236308, 0.14223999000575668, 1.1377885210003282, 0.10383036123335138, 0.7818826467906455, 3.9999986350005163, 1.1963949822474132e-9, 5.199494542850117e-9, 1.0429782092166001e-9, 0.06935599333405078, 1.2229941692266406e-9, 1.0424140223907133e-9, 1.3131954086807363e-9, 3.906428030104565e-9, 3.9996820204556705, 3.9998319930124047, 0.16113388726007818, 3.999999881365757, 3.999999124585335, 0.30714642048587315, 0.6217361987276203, 3.9919177865360105, 3.1003716221940314, 6.213165304311303]
#
# Starting optimization with optimizer DiffEvoOpt{FitPopulation{Float64}, RadiusLimitedSelector, BlackBoxOptim.AdaptiveDiffEvoRandBin{3}, RandomBound{ContinuousRectSearchSpace}}
# 0.00 secs, 0 evals, 0 steps
# DE modify state:
# 100.00 secs, 23520 evals, 23427 steps, improv/step: 0.131 (last = 0.1313), fitness=331.657503680
# DE modify state:
# 200.00 secs, 46052 evals, 45962 steps, improv/step: 0.134 (last = 0.1377), fitness=293.308196955
# DE modify state:
# 300.01 secs, 67307 evals, 67219 steps, improv/step: 0.135 (last = 0.1378), fitness=287.066904964
# DE modify state:
# 400.01 secs, 88889 evals, 88802 steps, improv/step: 0.143 (last = 0.1684), fitness=235.860973365
# DE modify state:
# 500.01 secs, 109590 evals, 109506 steps, improv/step: 0.144 (last = 0.1479), fitness=228.694523955
# DE modify state:
# 600.01 secs, 131092 evals, 131009 steps, improv/step: 0.144 (last = 0.1435), fitness=226.952920640
# DE modify state:
# 700.01 secs, 153974 evals, 153891 steps, improv/step: 0.143 (last = 0.1378), fitness=226.305177288
# DE modify state:
# 800.02 secs, 176233 evals, 176152 steps, improv/step: 0.143 (last = 0.1446), fitness=226.114577506
# DE modify state:
# 900.02 secs, 198626 evals, 198548 steps, improv/step: 0.142 (last = 0.1318), fitness=226.059782772
# DE modify state:
#
# Optimization stopped after 200001 steps and 906.55 seconds
# Termination reason: Max number of steps (200000) reached
# Steps per second = 220.62
# Function evals per second = 220.70
# Improvements/step = 0.14220
# Total function evaluations = 200077
#
#
# Best candidate found: [5.1994, 2.37567, 0.213181, 0.296232, 0.694845, 0.125815, 0.918097, 2.08435, 0.135839, 1.04398, 2.57692e-7, 4.33881e-8, 1.2226e-5, 0.122384, 6.48772e-6, 1.32398e-6, 2.53754e-6, 1.52977e-5, 0.112196, 0.91901, 2.76741, 3.99996, 3.99973, 3.99955, 0.410744, 0.932562, 2.3917, 8.44818]
#
# Fitness: 226.058263640
#
# Iteration 4
# 226.05826363981956
# [5.199401422330684, 2.3756741569459465, 0.2131812175821767, 0.29623224824703176, 0.6948446765471907, 0.1258151552498072, 0.9180972171096723, 2.0843465404618717, 0.13583856202570846, 1.0439843141937948, 2.576919827155264e-7, 4.338813586228748e-8, 1.2226040176831193e-5, 0.1223837293041803, 6.487716286097436e-6, 1.3239793105382527e-6, 2.5375410697781095e-6, 1.529765935365947e-5, 0.11219586779000636, 0.9190095981884465, 2.7674094254984083, 3.9999624688803808, 3.9997278014560433, 3.9995491493198436, 0.410743685081583, 0.9325617034404778, 2.3917017549498962, 8.44817576770869]
#
# Starting optimization with optimizer DiffEvoOpt{FitPopulation{Float64}, RadiusLimitedSelector, BlackBoxOptim.AdaptiveDiffEvoRandBin{3}, RandomBound{ContinuousRectSearchSpace}}
# 0.00 secs, 0 evals, 0 steps
# DE modify state:
# 100.00 secs, 19035 evals, 18915 steps, improv/step: 0.113 (last = 0.1132), fitness=383.781115714
# DE modify state:
# 200.00 secs, 33546 evals, 33427 steps, improv/step: 0.132 (last = 0.1557), fitness=298.158800106
# DE modify state:
# 300.01 secs, 46073 evals, 45955 steps, improv/step: 0.136 (last = 0.1490), fitness=285.746035004
# DE modify state:
# 400.01 secs, 59063 evals, 58946 steps, improv/step: 0.137 (last = 0.1401), fitness=279.337607333
# DE modify state:
# 500.02 secs, 72423 evals, 72306 steps, improv/step: 0.139 (last = 0.1468), fitness=258.532081412
# DE modify state:
# 600.02 secs, 86183 evals, 86068 steps, improv/step: 0.141 (last = 0.1509), fitness=227.629745781
# DE modify state:
# 700.03 secs, 100950 evals, 100838 steps, improv/step: 0.141 (last = 0.1387), fitness=223.207592020
# DE modify state:
# 800.03 secs, 115787 evals, 115675 steps, improv/step: 0.143 (last = 0.1621), fitness=222.108816861
# DE modify state:
# 900.03 secs, 130923 evals, 130811 steps, improv/step: 0.145 (last = 0.1607), fitness=219.691582164
# DE modify state:
# 1000.03 secs, 146131 evals, 146020 steps, improv/step: 0.147 (last = 0.1568), fitness=219.167224673
# DE modify state:
# 1100.03 secs, 160733 evals, 160622 steps, improv/step: 0.146 (last = 0.1417), fitness=219.128556496
# DE modify state:
# 1200.04 secs, 175365 evals, 175257 steps, improv/step: 0.145 (last = 0.1321), fitness=219.122241653
# DE modify state:
# 1300.04 secs, 190180 evals, 190074 steps, improv/step: 0.143 (last = 0.1164), fitness=219.121824605
# DE modify state:
#
# Optimization stopped after 200001 steps and 1368.35 seconds
# Termination reason: Max number of steps (200000) reached
# Steps per second = 146.16
# Function evals per second = 146.24
# Improvements/step = 0.14136
# Total function evaluations = 200105
#
#
# Best candidate found: [5.72663, 1.89101, 4.0, 0.346834, 0.61068, 0.657435, 0.62069, 0.485278, 3.99998, 0.466812, 2.83995e-8, 1.14305e-9, 7.19279e-9, 8.19107e-9, 1.36199e-9, 0.0933341, 5.78275e-8, 1.07002e-9, 3.99999, 0.162165, 2.79207, 3.88105, 1.55116, 4.0, 3.99998, 0.413066, 3.5561, 9.29304]
#
# Fitness: 219.121764272
#
# Iteration 5
# 219.12176427241783
# [5.726625548369553, 1.891011654207586, 3.999999427094521, 0.34683424344274666, 0.6106797531285673, 0.6574353431760973, 0.6206895220087066, 0.485278451917978, 3.999984042847429, 0.46681166501721644, 2.839946865998759e-8, 1.143049667146744e-9, 7.192790602405127e-9, 8.191070324880267e-9, 1.361993549321113e-9, 0.09333410516347342, 5.7827477134214364e-8, 1.0700247774384944e-9, 3.999994211889824, 0.16216538624085253, 2.7920697479511856, 3.88105073562753, 1.5511606162000717, 3.9999995008750746, 3.999980906913344, 0.4130660736627472, 3.5561022519263377, 9.293036741521558]
#
# Starting optimization with optimizer DiffEvoOpt{FitPopulation{Float64}, RadiusLimitedSelector, BlackBoxOptim.AdaptiveDiffEvoRandBin{3}, RandomBound{ContinuousRectSearchSpace}}
# 0.00 secs, 0 evals, 0 steps
# DE modify state:
# 100.00 secs, 19280 evals, 19191 steps, improv/step: 0.132 (last = 0.1320), fitness=364.592128137
# DE modify state:
# 200.00 secs, 40278 evals, 40189 steps, improv/step: 0.126 (last = 0.1197), fitness=291.136701625
# DE modify state:
# 300.01 secs, 60416 evals, 60327 steps, improv/step: 0.131 (last = 0.1428), fitness=224.365557992
# DE modify state:
# 400.01 secs, 81432 evals, 81343 steps, improv/step: 0.138 (last = 0.1554), fitness=212.792612472
# DE modify state:
# 500.02 secs, 102975 evals, 102887 steps, improv/step: 0.145 (last = 0.1716), fitness=212.546420429
# DE modify state:
# 600.02 secs, 124505 evals, 124418 steps, improv/step: 0.145 (last = 0.1454), fitness=212.543595464
# DE modify state:
# 700.02 secs, 145893 evals, 145806 steps, improv/step: 0.145 (last = 0.1429), fitness=212.543540965
# DE modify state:
# 800.03 secs, 167507 evals, 167424 steps, improv/step: 0.142 (last = 0.1280), fitness=212.543540007
# DE modify state:
# 900.03 secs, 188223 evals, 188141 steps, improv/step: 0.141 (last = 0.1342), fitness=212.543538812
# DE modify state:
#
# Optimization stopped after 200001 steps and 955.27 seconds
# Termination reason: Max number of steps (200000) reached
# Steps per second = 209.37
# Function evals per second = 209.45
# Improvements/step = 0.14048
# Total function evaluations = 200083
#
#
# Best candidate found: [4.02713, 2.51919, 4.0, 4.0, 1.00038e-9, 0.114004, 0.174451, 0.388886, 4.0, 0.733365, 1.2146e-9, 1.12186e-9, 0.0326245, 1.00419e-9, 1.00675e-9, 0.0164525, 1.09197e-9, 1.0338e-9, 4.0, 4.0, 4.0, 0.101412, 0.71691, 4.0, 4.0, 0.47265, 2.92679, 8.6175]
#
# Fitness: 212.543538337
#
# Iteration 6
# 212.543538337097
# [4.02713292386693, 2.5191900995785894, 3.999999998469615, 3.9999999291863, 1.0003754350286604e-9, 0.11400367648009335, 0.17445122284403905, 0.38888612761249386, 3.999999983035575, 0.7333648298828259, 1.2146040540407196e-9, 1.1218592747062676e-9, 0.032624514712689165, 1.0041942058283085e-9, 1.0067520061398603e-9, 0.016452531711603133, 1.091967335318166e-9, 1.0338006334207986e-9, 3.9999996607782258, 3.9999999802425514, 3.9999999927420076, 0.10141165162608536, 0.7169099156046851, 3.999999999404202, 3.9999991499834864, 0.4726497160521654, 2.9267930056038414, 8.617496873239771]
#
# Starting optimization with optimizer DiffEvoOpt{FitPopulation{Float64}, RadiusLimitedSelector, BlackBoxOptim.AdaptiveDiffEvoRandBin{3}, RandomBound{ContinuousRectSearchSpace}}
# 0.00 secs, 0 evals, 0 steps
# DE modify state:
# 100.00 secs, 19360 evals, 19230 steps, improv/step: 0.134 (last = 0.1336), fitness=387.977547688
# DE modify state:
# 200.01 secs, 34459 evals, 34330 steps, improv/step: 0.150 (last = 0.1702), fitness=293.793878949
# DE modify state:
# 300.01 secs, 49129 evals, 49000 steps, improv/step: 0.147 (last = 0.1395), fitness=260.396941814
# DE modify state:
# 400.01 secs, 64701 evals, 64573 steps, improv/step: 0.144 (last = 0.1337), fitness=226.149578433
# DE modify state:
# 500.01 secs, 81142 evals, 81016 steps, improv/step: 0.143 (last = 0.1389), fitness=215.846664500
# DE modify state:
# 600.02 secs, 97881 evals, 97755 steps, improv/step: 0.144 (last = 0.1531), fitness=214.043639174
# DE modify state:
# 700.02 secs, 114746 evals, 114620 steps, improv/step: 0.146 (last = 0.1569), fitness=213.814077811
# DE modify state:
# 800.02 secs, 131511 evals, 131386 steps, improv/step: 0.145 (last = 0.1371), fitness=213.802010511
# DE modify state:
# 900.03 secs, 146321 evals, 146197 steps, improv/step: 0.143 (last = 0.1282), fitness=213.801260047
# DE modify state:
# 1000.03 secs, 159062 evals, 158938 steps, improv/step: 0.141 (last = 0.1198), fitness=213.801079030
# DE modify state:
# 1100.03 secs, 171694 evals, 171571 steps, improv/step: 0.141 (last = 0.1283), fitness=213.800970047
# DE modify state:
# 1200.03 secs, 187709 evals, 187587 steps, improv/step: 0.140 (last = 0.1342), fitness=213.800523724
# DE modify state:
#
# Optimization stopped after 200001 steps and 1279.20 seconds
# Termination reason: Max number of steps (200000) reached
# Steps per second = 156.35
# Function evals per second = 156.44
# Improvements/step = 0.13895
# Total function evaluations = 200122
#
#
# Best candidate found: [5.49634, 1.92636, 0.347049, 1.03484, 0.895963, 0.780791, 1.21793, 1.01149, 0.443916, 0.35318, 1.025e-8, 1.60495e-8, 2.57438e-8, 2.48602e-8, 3.38861e-8, 8.06424e-9, 0.096271, 4.29098e-9, 0.157646, 3.9995, 3.99996, 3.99997, 3.99997, 2.43022, 4.0, 0.320361, 3.49788, 8.29793]
#
# Fitness: 213.800246324
#
# Iteration 7
# 213.8002463237605
# [5.496342778293916, 1.9263635801592733, 0.347049283660269, 1.0348361701968438, 0.895962928379265, 0.7807906443020664, 1.2179316950231753, 1.0114873711985661, 0.44391634371031174, 0.35318006962566706, 1.0250027291383698e-8, 1.6049543103975033e-8, 2.5743761515954174e-8, 2.4860212248938222e-8, 3.388611195211421e-8, 8.064244538984447e-9, 0.09627097810244495, 4.2909755095628736e-9, 0.15764635154862952, 3.999496334992096, 3.9999591406276602, 3.9999743644971764, 3.9999690985126626, 2.4302187448066546, 3.9999991469686202, 0.320360857123713, 3.497876071927259, 8.297929274495724]
#
# Starting optimization with optimizer DiffEvoOpt{FitPopulation{Float64}, RadiusLimitedSelector, BlackBoxOptim.AdaptiveDiffEvoRandBin{3}, RandomBound{ContinuousRectSearchSpace}}
# 0.00 secs, 0 evals, 0 steps
# DE modify state:
# 100.00 secs, 18590 evals, 18471 steps, improv/step: 0.096 (last = 0.0958), fitness=447.800617124
# DE modify state:
# 200.01 secs, 31953 evals, 31834 steps, improv/step: 0.121 (last = 0.1557), fitness=309.272703685
# DE modify state:
# 300.01 secs, 46032 evals, 45913 steps, improv/step: 0.127 (last = 0.1415), fitness=288.237220383
# DE modify state:
# 400.01 secs, 65077 evals, 64958 steps, improv/step: 0.135 (last = 0.1537), fitness=244.007257015
# DE modify state:
# 500.01 secs, 83897 evals, 83781 steps, improv/step: 0.139 (last = 0.1545), fitness=220.193395905
# DE modify state:
# 600.01 secs, 101461 evals, 101347 steps, improv/step: 0.141 (last = 0.1464), fitness=216.955348474
# DE modify state:
# 700.02 secs, 116763 evals, 116650 steps, improv/step: 0.144 (last = 0.1643), fitness=214.572792617
# DE modify state:
# 800.02 secs, 133800 evals, 133687 steps, improv/step: 0.145 (last = 0.1571), fitness=213.312425674
# DE modify state:
# 900.02 secs, 153969 evals, 153859 steps, improv/step: 0.144 (last = 0.1339), fitness=213.018982413
# DE modify state:
# 1000.02 secs, 173165 evals, 173055 steps, improv/step: 0.143 (last = 0.1363), fitness=212.967888110
# DE modify state:
# 1100.03 secs, 190817 evals, 190708 steps, improv/step: 0.142 (last = 0.1306), fitness=212.964166137
# DE modify state:

# %%
println(g_costs)
println(g_hills)
